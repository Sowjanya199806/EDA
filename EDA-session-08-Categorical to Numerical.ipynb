# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine_data=pd.read_csv(r"C:\Users\sowja\OneDrive\Naresh IT\Data_Files\winequality_red.csv")
wine_data

# %%
wine_data.drop_duplicates()

# %%
wine_data=wine_data.drop_duplicates()
wine_data.iloc[1:,:]   # when we do this the index values will not in order
                       # now we need to work on this how to make order

# %%
wine_data.columns

# %%
len(wine_data.columns)

# %%
# 12*12=144
wine_data.corr()

# %% [markdown]
# **Heat map**

# %% [markdown]
# - heat map provide the matrix representation of correlatio value
#
# - heat map represents value in color format
#
# - diff diff values in diff color
#
# - beside matrix it will display color bar
#
# - color bar means like a scale of values with color
#
# - it is unders seaborn packages
#
# - # to check the higher and lower values in colors

# %%
wine_corr=wine_data.corr()
plt.figure(figsize=(10,6))
sns.heatmap(wine_corr,annot=True)

# %%
import seaborn as sns
sns._version_

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
visa_df.head(3)

# %%
visa_corr=visa_df.corr(numeric_only=True)
sns.heatmap(visa_corr,
            annot=True)

# %%
wine_data.row # it does't work

# %% [markdown]
# **Import the packages**

# %%
10/06/1998

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Categorical to Numerical**
#
# - It is very importent convert categorical data to numerical data
#
# - Because in Machine learning models the input is in the form numbers
#
# - Ml models developed by maths, so passing text data is not works
#
# - We have diiferent types of methods are there
#     - Map Method
#
#     - np.Where
#
#     - One hot encoder
#
#     - Label encoder

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#**Categorical columns**
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **Map**
#
# - first get the unique labels foe each coumn
#
# - create a dictonary by providing a values to each label
#
# - for example case status has 2 labes,we are provding 2 values
#
#              - Assign 0 for certified
#
#              - Assign 1 for certified

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Denied':1,'certified':0}
d
# Out:
# {'Denied': 1, 'certified': 0}

# %%
# visa_df['case_status'].map(d)

# %%
visa_df['case_status_New']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#Replacing the case status to new (override)
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
d={'Denied':1,'certified':0}
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d2={'Y':1,'N':0}
visa_df['has_job_experience']=visa_df['has_job_experience'].map(d2)
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
**Task**

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
len(visa_df['case_status'].unique())
d={'Denied': 1,'certified': 0}
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
**Label encoder**

  - label encoder is a package under **Sickit learn**
  - Sickit learn is heart of Machine learning
  - In side Sickit - learn we have a method called **Preprocessing**
  - Under preprocessing we have **LableEncoder**
  - Sickit - learn we will write as **Sklearn**
- Any sklearn package we have 3 steps
   - step-1 Read the package
   - step-2 Save the package
   - step-3 apply the fit transform

# %% [raw]
# # Read the data again
# visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
# visa_df.head(3)

# %%
#   - step-1 Read the package
from sklearn.preprocessing import LabelEncoder
#   - step-2 Save the package
le=LabelEncoder()
#   - step-3 apply the fit transform
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#   - step-1 Read the package
from sklearn.preprocessing import LabelEncoder
#   - step-2 Save the package
le=LabelEncoder()
#   - step-3 apply the fit transform
visa_df['education_of_employee']=le.fit_transform(visa_df['education_of_employee'])

# %%
visa_df
# Out:
#          case_id continent  education_of_employee has_job_experience  \
# 0         EZYV01      Asia                      2                  N
# 1         EZYV02      Asia                      3                  Y
# 2         EZYV03      Asia                      0                  N
# 3         EZYV04      Asia                      0                  N
# 4         EZYV05    Africa                      3                  Y
# ...          ...       ...                    ...                ...
# 25475  EZYV25476      Asia                      0                  Y
# 25476  EZYV25477      Asia                      2                  Y
# 25477  EZYV25478      Asia                      3                  Y
# 25478  EZYV25479      Asia                      3                  Y
# 25479  EZYV25480      Asia                      0                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#   - step-1 Read the package
from sklearn.preprocessing import LabelEncoder
#   - step-2 Save the package
le=LabelEncoder()
#   - step-3 apply the fit transform
visa_df['has_job_experience']=le.fit_transform(visa_df['has_job_experience'])

# %%
visa_df
# Out:
#          case_id continent  education_of_employee  has_job_experience  \
# 0         EZYV01      Asia                      2                   0
# 1         EZYV02      Asia                      3                   1
# 2         EZYV03      Asia                      0                   0
# 3         EZYV04      Asia                      0                   0
# 4         EZYV05    Africa                      3                   1
# ...          ...       ...                    ...                 ...
# 25475  EZYV25476      Asia                      0                   1
# 25476  EZYV25477      Asia                      2                   1
# 25477  EZYV25478      Asia                      3                   1
# 25478  EZYV25479      Asia                      3                   1
# 25479  EZYV25480      Asia                      0                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)
visa_df

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
cols=visa_df.select_dtypes(include='object').columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df

# inorder to read the aphabets (words) we need to do individually
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Inverese transform**
#
# - in order to see inverse of labeles we need to perform individually again

# %%
le.inverse_transform(visa_df['continent'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 le.inverse_transform(visa_df['continent'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:162, in LabelEncoder.inverse_transform(self, y)
#     160 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     161 if len(diff):
# --> 162     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     163 y = np.asarray(y)
#     164 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [2 3 4 5]

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

visa_df['case_status']=le.fit_transform(visa_df['case_status'])
print(visa_df['case_status'].values) # why we are applying values
print(le.inverse_transform(visa_df['case_status']))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# **LableEncoder will use most of the time**

# %%
****

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
con=visa_df['case_status']=='Certified'
visa_df
