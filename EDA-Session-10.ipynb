# %% [markdown]
# **Data transformations**
#
# - Generally data has 3 types of distribution
#
#    - Normal distribution
#
#    - Positive skewed
#
#    - Negative skewed
#
# - All the maths concepts developed by assumption as Data follows Normal distribution
#
# - Data skew happens because of many reasons , in that one reason is ouliers
#
# - Once we perform the outlier analysis then we can apply transformation methods,if the data does not follows normality
#
# - we have some transformation methods mentioned below
#
# - we have some transformation method mentioned below
#    -

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $Step-1$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $Step-2$

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.87602004, 0.15543274, 0.35895798, ..., 0.09147176, 0.22771046,
#        0.68273981])

# %% [markdown]
# $Step-3$

# %% [markdown]
# **Plot the data**

# %%
plt.hist(exp_data,bins=20,label='Exponential')   # bins=intervals
plt.show()

# %%
norm_data=np.random.exponential(size=10000)
norm_data
# Out:
# array([2.02937083, 0.01420613, 0.01927332, ..., 0.24360549, 0.25211231,
#        1.6868674 ])

# %%
**Goal**
  
**The goal is to convert exp_data to normal distribution**

    - Log transformation means performing logrithm operations on original data
    
    - It is an approach to convert into Normal distribution

    - Log means natural logrithm base=e

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
x=2
np.log(x)

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.07138967, 1.27142577, 1.96611332, ..., 0.23214558, 0.48202822,
#        0.96957808])

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([-2.63960204,  0.24013892,  0.67605866, ..., -1.4603906 ,
#        -0.72975261, -0.03089427])

# %%
plt.hist(log_data,bins=20,label='Logarithm')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# **Reciprocal Transformations**

# %% [markdown]
# **Square root Transformations**

# %% [raw]
# **Power Transformation**
# - Box cox
# - Ye-jhonson
# - It is under sklearn preprocessing

# %% [raw]
# import numpy as np
# from sklearn.preprocessing import power_transform
# # save
# # apply fit transform

# %%
import numpy as np
from sklearn.preprocessing import power_transform
power = powerTransformation(method='yeo-johnson',standardize=True)
data_trans=

# %%
exp_data
# Out:
# array([0.07138967, 1.27142577, 1.96611332, ..., 0.23214558, 0.48202822,
#        0.96957808])

# %%
exp_data.reshape(-1,1)
# Out:
# array([[0.07138967],
#        [1.27142577],
#        [1.96611332],
#        ...,
#        [0.23214558],
#        [0.48202822],
#        [0.96957808]])
