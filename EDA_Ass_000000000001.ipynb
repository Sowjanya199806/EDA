# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# 1 series

visa_df['education_of_employee']=='High School'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476     True
# 25477    False
# 25478    False
# 25479    False
# Name: education_of_employee, Length: 25480, dtype: bool

# %%
# 2 DataFrame

ed=visa_df['education_of_employee']=='High School'
visa_df[ed]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 11        EZYV12           Asia           High School                  Y
# 15        EZYV16           Asia           High School                  Y
# 23        EZYV24  North America           High School                  N
# 27        EZYV28           Asia           High School                  Y
# ...          ...            ...                   ...                ...
# 25463  EZYV25464           Asia           High School                  N
# 25465  EZYV25466  North America           High School                  N
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# 3 total

unique_ed=visa_df['education_of_employee'].unique()
for i in unique_ed:
    ed=visa_df['education_of_employee']==i
    val=len(visa_df[ed])
    print(val)
# Out:
# 3420
# 9634
# 10234
# 2192

# %%
# 4  education and total

unique_ed=visa_df['education_of_employee'].unique()
for i in unique_ed:
    ed=visa_df['education_of_employee']==i
    val=len(visa_df[ed])
    print(f"{i}  : {val}")
# Out:
# High School  : 3420
# Master's  : 9634
# Bachelor's  : 10234
# Doctorate  : 2192

# %%
# Task - 2 Creating in a tabular form Excel

# 5

unique_ed=visa_df['education_of_employee'].unique()
count_list=[]
for i in unique_ed:
    edu=visa_df['education_of_employee']==i
    val=len(visa_df[edu])
    count_list.append(val)

# %%
# 6

education_df=pd.DataFrame(zip(unique_ed,count_list),
                         columns=['education_of_employee','Count'])

# %%
# 7

education_df.to_csv('education_of_employee_df.csv',index=False)

# %%
# short cut

visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
# Second

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
visa_df['case_status'].nunique()
# Out:
# 2

# %%
# 1 Series(T/F)

visa_df['case_status']=='Certified'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: case_status, Length: 25480, dtype: bool

# %%
# 2  dataFrame

case=visa_df['case_status']=='Certified'
visa_df[case]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 4         EZYV05    Africa              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
# 3 Length

case=visa_df['case_status']=='Certified'
len(visa_df[case])
# Out:
# 17018

# %%
# 4  education and total

unique_case=visa_df['case_status'].unique()
for i in unique_case:
    case=visa_df['case_status']==i
    val=len(visa_df[case])
    print(f"{i}  : {val}")
# Out:
# Denied  : 8462
# Certified  : 17018

# %%
# 5

unique_case=visa_df['case_status'].unique()
count_list=[]

for i in unique_case:
    case=visa_df['case_status']==i
    val=len(visa_df[case])
    count_list.append(val)

###################################################
case_df=pd.DataFrame(zip(unique_case,count_list),
                    columns=['case_status','Count'])

#################################################
case_df.to_csv('case_status_df.csv',index=False)

# %%
# 6

visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %% [markdown]
# # Third

# %%
visa_df['region_of_employment'].unique()
# Out:
# array(['West', 'Northeast', 'South', 'Midwest', 'Island'], dtype=object)

# %%
visa_df['region_of_employment'].nunique()
# Out:
# 5

# %%
#1
visa_df['region_of_employment']=='South'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 25475     True
# 25476    False
# 25477     True
# 25478    False
# 25479    False
# Name: region_of_employment, Length: 25480, dtype: bool

# %%
# 2
region=visa_df['region_of_employment']=='South'
visa_df[region]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 4         EZYV05         Africa              Master's                  Y
# 5         EZYV06           Asia              Master's                  Y
# 6         EZYV07           Asia            Bachelor's                  N
# 9         EZYV10         Europe             Doctorate                  Y
# 14        EZYV15           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25456  EZYV25457           Asia            Bachelor's                  Y
# 25464  EZYV25465           Asia              Master's                  N
# 25465  EZYV25466  North America           High School                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25477  EZYV25478           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# 2
region=visa_df['region_of_employment']=='South'
len(visa_df[region])
# Out:
# 7017

# %%
# 3

unique_region=visa_df['region_of_employment'].unique()
for i in unique_region:
    reg= visa_df['region_of_employment']==i
    val=len(visa_df[reg])
    print(f"{i} : {val}")
# Out:
# West : 6586
# Northeast : 7195
# South : 7017
# Midwest : 4307
# Island : 375

# %%
#4 
unique_region=visa_df['region_of_employment'].unique()
count_list=[]

for i in unique_region:
    reg= visa_df['region_of_employment']==i
    val=len(visa_df[reg])
    count_list.append(val)

########################################################
employment_df=pd.DataFrame(zip(unique_region,count_list),
                          columns=['region_of_employment','count'])

#######################################################
employment_df.to_csv('region_of_employment_df.csv',index=False)

# %%
# 5
visa_df['region_of_employment'].value_counts()
# Out:
# region_of_employment
# Northeast    7195
# South        7017
# West         6586
# Midwest      4307
# Island        375
# Name: count, dtype: int64
