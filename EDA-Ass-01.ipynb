# %%
30/05/2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\sowja\Downloads\Visadataset - Visadataset (2).csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
ed=visa_df['education_of_employee']=='High School'
visa_df[ed]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 11        EZYV12           Asia           High School                  Y
# 15        EZYV16           Asia           High School                  Y
# 23        EZYV24  North America           High School                  N
# 27        EZYV28           Asia           High School                  Y
# ...          ...            ...                   ...                ...
# 25463  EZYV25464           Asia           High School                  N
# 25465  EZYV25466  North America           High School                  N
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
unique_ed=visa_df['education_of_employee'].unique()
for i in unique_ed:
    ed=visa_df['education_of_employee']==i
    val=len(visa_df[ed])
    print(f"{i}  : {val}")
# Out:
# High School  : 3420
# Master's  : 9634
# Bachelor's  : 10234
# Doctorate  : 2192

# %%
unique_ed=visa_df['education_of_employee'].unique()
count_list=[]
for i in unique_ed:
    edu=visa_df['education_of_employee']==i
    val=len(visa_df[edu])
    count_list.append(val)

#####################################################
education_df=pd.DataFrame(zip(unique_ed,count_list),
                         columns=['education_of_employee','Count'])
######################################################
education_df.to_csv('education_of_employee_df.csv',index=False)

# %%
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
eoe=visa_df['education_of_employee'].value_counts()
eoe
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
eoe.values
# Out:
# array([10234,  9634,  3420,  2192], dtype=int64)

# %%
plt.bar('education_of_employee','Count',data=education_df)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(5,2))
plt.bar('education_of_employee','Count',data=education_df)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.savefig("barchart.jpg")
plt.savefig("barchart.png")
plt.show()

# %%
plt.figure(figsize=(5,2))
sns.countplot(data=visa_df,x='education_of_employee')
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.show()

# %%
eoe=visa_df['education_of_employee'].value_counts()
eoe.keys()
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
eoe=visa_df['education_of_employee'].value_counts()
keys=eoe.keys()

plt.figure(figsize=(5,2))
sns.countplot(data=visa_df,
              x='education_of_employee',
             order=keys)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.show()

# %%
eoe=visa_df['education_of_employee'].value_counts()
keys=eoe.keys()
ax=eoe.plot(kind='bar')
ax.bar_label(ax.containers[0])

plt.figure(figsize=(5,2))
sns.countplot(data=visa_df,
              x='education_of_employee',
             order=keys)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.show()

# %%
eoe=visa_df['education_of_employee'].value_counts()
ax=eoe.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# $SUBPLOTS$

# %%
plt.figure(figsize=(5,2))
plt.subplot(2,1,2)
plt.bar('education_of_employee','Count',data=education_df)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.savefig("barchart.jpg")
plt.savefig("barchart.png")
plt.show()

# %%
eoe=visa_df['education_of_employee'].value_counts()
keys=eoe.keys()

plt.figure(figsize=(5,2))
plt.subplot(2,1,1)
sns.countplot(data=visa_df,
              x='education_of_employee',
             order=keys)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.show()

# %%
#Matplotlib
plt.subplot(1,2,2).bar('education_of_employee','Count',data=education_df)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.savefig("barchart.jpg")
plt.savefig("barchart.png")
plt.show()

# sear born#############################################
eoe=visa_df['education_of_employee'].value_counts()
keys=eoe.keys()

plt.subplot(1,1,1)
sns.countplot(data=visa_df,
              x='education_of_employee',
             order=keys)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.show()

# %%
eoe=visa_df['education_of_employee'].value_counts()
keys=eoe.keys()

plt.subplot(2,1,1)
sns.countplot(data=visa_df,
              x='education_of_employee',
             order=keys)
plt.title("Bar chart")
plt.xlabel("education_of_employee")
plt.ylabel("Count")
plt.show()

# %%
visa_df['education_of_employee'].value_counts(normalize=True)
# Out:
# education_of_employee
# Bachelor's     0.401648
# Master's       0.378100
# High School    0.134223
# Doctorate      0.086028
# Name: proportion, dtype: float64

# %%
eoe=visa_df['education_of_employee'].value_counts()
keys=eoe.keys()
values=eoe.values
keys,values
# Out:
# (Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee'),
#  array([10234,  9634,  3420,  2192], dtype=int64))

# %%
plt.pie(values)
# Out:
# ([<matplotlib.patches.Wedge at 0x19e0ec08590>,
# ...
#  [Text(0.3344966922241296, 1.0479083752366503, ''),
#   Text(-0.9261646618060718, -0.5934804286761652, ''),
#   Text(0.6288833423908359, -0.9024997183729925, ''),
#   Text(1.0600699942929763, -0.293686239377485, '')])

# %%
plt.pie(values,
        explode=[0.1,0.1,0.1,0.1],
        labels=keys,
        autopct="%0.2f%%",
        startangle=360,
        radius=1)
plt.show()
